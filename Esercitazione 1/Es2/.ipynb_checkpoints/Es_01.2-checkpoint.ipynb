# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import curve_fit

# %%
path = "Std.out"

n_bins = 100

N = np.loadtxt(path, usecols=(0), delimiter=' ', unpack='true', max_rows=1)
M = np.loadtxt(path, usecols=(0, 1, 2, 3), delimiter=' ', unpack='true', skiprows=1, max_rows=1)

v1, v2, v3, v4 = np.loadtxt(path, usecols=(0, 1, 2 ,3), delimiter=' ', unpack='true', skiprows=2)

fig, ((ax1,ax2), (ax3,ax4))=plt.subplots(2, 2, figsize=(20, 15))

fig.suptitle("Uniform Dice", size = 20)

ax1.hist(v1, bins=n_bins, color='cornflowerblue', density=True)
ax1.set_xlabel("Value")
ax1.set_ylabel("# counts")
ax1.set_title("Standard Distibution, N = " +str(int(M[0])))

ax2.hist(v2, bins=n_bins, color='darkorange', density=True)
ax2.set_xlabel("Value")
ax2.set_ylabel("# counts")
ax2.set_title("Standard Distibution, N = " +str(int(M[1])))

ax3.hist(v3, bins=n_bins, color='lightcoral', density=True)
ax3.set_xlabel("Value")
ax3.set_ylabel("# counts")
ax3.set_title("Standard Distibution, N = " +str(int(M[2])))

ax4.hist(v4, bins=n_bins, color='lightseagreen', density=True)
ax4.set_xlabel("Value")
ax4.set_ylabel("# counts")
ax4.set_title("Standard Distibution, N = " +str(int(M[3])))

plt.show()

# %%
def gaussian (x, mean, width, std_dev):
    return width * np.exp( - (x-mean)**2 / (2*std_dev)**2)

# %%
path = "Exp.out"

n_bins = 100

N = np.loadtxt(path, usecols=(0), delimiter=' ', unpack='true', max_rows=1)
M = np.loadtxt(path, usecols=(0, 1, 2, 3), delimiter=' ', unpack='true', skiprows=1, max_rows=1)

v1, v2, v3, v4 = np.loadtxt(path, usecols=(0, 1, 2 ,3), delimiter=' ', unpack='true', skiprows=2)

fig, ((ax1,ax2), (ax3,ax4))=plt.subplots(2, 2, figsize=(20, 15))

fig.suptitle("Exponential Dice", size = 20)
      
data_entries, bins=np.histogram(v4, bins=n_bins, density = True)
bincenter=np.array([(bins[i]+bins[i+1])/2 for i in np.arange (n_bins)])

popt, pcov = curve_fit(gaussian, xdata = bincenter, ydata=data_entries)

ax4.plot(bincenter, gaussian(bincenter, *popt), color = 'red', linewidth = 4)

ax1.hist(v1, bins=n_bins, color='blue', density=True)
ax1.set_xlabel("Value")
ax1.set_ylabel("# counts")
ax1.set_title("Standard Distibution, N = " +str(int(M[0])))

ax2.hist(v2, bins=n_bins, color='blue', density=True)
ax2.set_xlabel("Value")
ax2.set_ylabel("# counts")
ax2.set_title("Standard Distibution, N = " +str(int(M[1])))

ax3.hist(v3, bins=n_bins, color='blue', density=True)
ax3.set_xlabel("Value")
ax3.set_ylabel("# counts")
ax3.set_title("Standard Distibution, N = " +str(int(M[2])))

ax4.hist(v4, bins=n_bins, color='blue', density=True)
ax4.set_xlabel("Value")
ax4.set_ylabel("# counts")
ax4.set_title("Standard Distibution, N = " +str(int(M[3])))

plt.show()

# %%
def lorentzian (x, mean, width):
    return 1/(np.pi()) * (0.5*width/((x-mean)**2+(0.5*width)**2))

# %%
path = "Lor.out"

n_bins = 100

N = np.loadtxt(path, usecols=(0), delimiter=' ', unpack='true', max_rows=1)
M = np.loadtxt(path, usecols=(0, 1, 2, 3), delimiter=' ', unpack='true', skiprows=1, max_rows=1)

v1, v2, v3, v4 = np.loadtxt(path, usecols=(0, 1, 2 ,3), delimiter=' ', unpack='true', skiprows=2)

fig, ((ax1,ax2), (ax3,ax4))=plt.subplots(2, 2, figsize=(20, 15))

fig.suptitle("Lorentzian Dice", size = 20)
      
data_entries, bins=np.histogram(v4, bins=n_bins, density = True)
binscenters=np.array([(bins[i]+bins[i+1])/2 for i in np.arange (n_bins)])

popt, pcov = curve_fit(lorentzian, xdata = bincenter, ydata=data_entries)

ax4.plot(bincenter, lorentzian(bincenter, *popt), color = 'red', linewidth = 4)

ax1.hist(v1, bins=n_bins, color='blue',density=True, range=(-10,10))
ax1.set_xlabel("Value")
ax1.set_ylabel("# counts")
ax1.set_title("Standard Distibution, N = " +str(int(M[0])))

ax2.hist(v2, bins=n_bins, color='blue', density=True, range=(-10,10))
ax2.set_xlabel("Value")
ax2.set_ylabel("# counts")
ax2.set_title("Standard Distibution, N = " +str(int(M[1])))

ax3.hist(v3, bins=n_bins, color='blue', density=True, range=(-10,10))
ax3.set_xlabel("Value")
ax3.set_ylabel("# counts")
ax3.set_title("Standard Distibution, N = " +str(int(M[2])))

ax4.hist(v4, bins=n_bins, color='blue', density=True, range=(-10,10))
ax4.set_xlabel("Value")
ax4.set_ylabel("# counts")
ax4.set_title("Standard Distibution, N = " +str(int(M[3])))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/k5/16lr6vn97r14d8hp8hts49z40000gn/T/ipykernel_63144/4054081926.py in <module>
#      15 binscenters=np.array([(bins[i]+bins[i+1])/2 for i in np.arange (n_bins)])
#      16
# ---> 17 popt, pcov = curve_fit(lorentzian, xdata = bincenter, ydata=data_entries)
#      18
#      19 ax4.plot(bincenter, lorentzian(bincenter, *popt), color = 'red', linewidth = 4)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     787         # Remove full_output from kwargs, otherwise we're passing it in twice.
#     788         return_full = kwargs.pop('full_output', False)
# --> 789         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     790         popt, pcov, infodict, errmsg, ier = res
#     791         ysize = len(infodict['fvec'])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     408     if not isinstance(args, tuple):
#     409         args = (args,)
# --> 410     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     411     m = shape[0]
#     412
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py in func_wrapped(params)
#     483     if transform is None:
#     484         def func_wrapped(params):
# --> 485             return func(xdata, *params) - ydata
#     486     elif transform.ndim == 1:
#     487         def func_wrapped(params):
#
# /var/folders/k5/16lr6vn97r14d8hp8hts49z40000gn/T/ipykernel_63144/1909420835.py in lorentzian(x, mean, width)
#       1 def lorentzian (x, mean, width):
# ----> 2     return 1/(np.pi()) * (0.5*width/((x-mean)**2+(0.5*width)**2))
#
# TypeError: 'float' object is not callable
