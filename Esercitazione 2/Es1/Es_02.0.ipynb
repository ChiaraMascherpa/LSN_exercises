# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import curve_fit

# %%
path = "File.out"

M, N = np.loadtxt(path, usecols=(0, 1), delimiter=' ', unpack='true', max_rows=1)

ave1, ave2, std1, std2 = np.loadtxt(path, usecols=(0, 1, 2 ,3), delimiter=' ', unpack='true', skiprows=1)

x = np.arange(N)
L=int(M/N)
x*=L # Number of throws = block * (Number of throws in each block)

graph1=plt.errorbar(x,ave1-1,yerr=std1, label = "uniform sampling")
graph2=plt.errorbar(x,ave2-1,yerr=std2, label = "importance sampling using 2(1-x)")
plt.xlabel('# throws')
plt.ylabel('mean value')
plt.grid(True)
plt.legend(handler_map={line1: HandlerLine2D(numpoints=4)})

plt.show()
